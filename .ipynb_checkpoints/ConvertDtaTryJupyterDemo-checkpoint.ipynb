# %% [markdown]
# # Step One: Go over to the *Try Jupyter* site
#
# Located here: [Try Jupyter](http://jupyter.org/try) option at http://jupyter.org/try. (Click on the "Try Jupyter with Python" link).
#
# # Step Two : Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Step Three: Open your dta file.
# When using hub the [Try Jupyter](http://jupyter.org/try) option at http://jupyter.org/try, consider depositing your dta file at an accessible http location.

# %%
cfile = pd.read_stata('http://www.stata-press.com/data/r15/auto2.dta')

# %% [markdown]
# # Step Four: Display the data frame.
# After display you can check your results. I working on a local computer you can export to xls, csv, etc.
#
# However, if you are using [Try Jupyter](http://jupyter.org/try) option at http://jupyter.org/try you will have to copy and paste the results to another application.

# %%
cfile
# Out:
#                  make  price  mpg      rep78  headroom  trunk  weight  length  \
# 0         AMC Concord   4099   22    Average       2.5     11    2930     186
# 1           AMC Pacer   4749   17    Average       3.0     11    3350     173
# 2          AMC Spirit   3799   22        NaN       3.0     12    2640     168
# 3       Buick Century   4816   20    Average       4.5     16    3250     196
# 4       Buick Electra   7827   15       Good       4.0     20    4080     222
# 5       Buick LeSabre   5788   18    Average       4.0     21    3670     218
# 6          Buick Opel   4453   26        NaN       3.0     10    2230     170
# 7         Buick Regal   5189   20    Average       2.0     16    3280     200
# 8       Buick Riviera  10372   16    Average       3.5     17    3880     207
# 9       Buick Skylark   4082   19    Average       3.5     13    3400     200
# 10       Cad. Deville  11385   14    Average       4.0     20    4330     221
# ...
